# %%
import pandas as pd

# %%
m_area = pd.read_csv("../notebooks/m_area.csv")
m_area.head()
# Out:
#   area_cd wide_area narrow_area
# 0      TK        東京          東京
# 1      KN       神奈川         神奈川
# 2      CH        千葉          千葉
# 3      SA        埼玉          埼玉
# 4      IB       北関東          茨城

# %%
m_store = pd.read_csv("../notebooks/m_store.csv")
m_store.head()
# Out:
#    store_id store_name area_cd
# 0         1        昭島店      TK
# 1         2      あきる野店      TK
# 2         3        足立店      TK
# 3         4       北千住店      TK
# 4         5        綾瀬店      TK

# %%
tbl_order_4 = pd.read_csv("../notebooks/tbl_order_202004.csv")
tbl_order_4.head()
# Out:
#    order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0  79339111        49   C26387220         50         67393872
# 1  18941733        85   C48773811         26         91834983
# 2  56217880        76   C66287421         36         64409634
# 3  28447783       190   C41156423         19         73032165
# 4  32576156       191   C54568117         71         23281182
#
#      order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0  2020-04-01 11:00:00  2020-04-01 11:18:00             1          4144
# 1  2020-04-01 11:00:00  2020-04-01 11:22:00             0          2877
# 2  2020-04-01 11:00:00  2020-04-01 11:15:00             0          2603
# 3  2020-04-01 11:00:00  2020-04-01 11:16:00             0          2732
# 4  2020-04-01 11:00:00  2020-04-01 11:53:00             0          2987
#
#    status
# 0       1
# 1       2
# 2       2
# 3       2
# 4       2

# %%
tbl_order_4.shape
# Out:
# (233260, 10)

# %%
tbl_order_5 = pd.read_csv("../notebooks/tbl_order_202005.csv")
tbl_order_5.head()
# Out:
#    order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0  24742472        22   C90731046         22         80308413
# 1  11342919        56   C68678177         12         35725624
# 2  76451864        56   C79630016         46          2609869
# 3  28392539       192   C83895707         80         17111162
# 4  71706591       121   C36584528         93         22800835
#
#      order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0  2020-05-01 11:00:00  2020-05-01 11:22:00             1          2328
# 1  2020-05-01 11:00:00  2020-05-01 11:50:00             0          2987
# 2  2020-05-01 11:00:00  2020-05-01 11:32:00             0          2603
# 3  2020-05-01 11:00:00  2020-05-01 11:19:00             0          2603
# 4  2020-05-01 11:00:00  2020-05-01 11:17:00             0          2877
#
#    status
# 0       1
# 1       2
# 2       2
# 3       2
# 4       2

# %%
tbl_order_5.shape
# Out:
# (241139, 10)

# %%
tbl_order_6 = pd.read_csv("../notebooks/tbl_order_202006.csv")
tbl_order_6.head()
# Out:
#    order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0  16514392        64   C44271355         49         56527968
# 1  28342394        12   C98307866         98         46924304
# 2  29799587       174   C59484037         45         47054474
# 3  96960753        23   C57278332         70         60848267
# 4  52147209         7   C36890849         80         20633593
#
#      order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0  2020-06-01 11:00:00  2020-06-01 11:55:00             0          2732
# 1  2020-06-01 11:00:00  2020-06-01 11:52:00             0          2064
# 2  2020-06-01 11:00:00  2020-06-01 11:25:00             0          3900
# 3  2020-06-01 11:00:00  2020-06-01 11:45:00             0          2750
# 4  2020-06-01 11:00:00  2020-06-01 11:23:00             0          2328
#
#    status
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2

# %%
concat_4_and_5 = pd.concat([tbl_order_4, tbl_order_5], ignore_index=True)
concat_4_and_5.shape
# Out:
# (474399, 10)

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks'

# %%
os.listdir(current_dir)
# Out:
# ['chap1.ipynb',
#  'tbl_order_202006.csv',
#  'tbl_order_202004.csv',
#  'tbl_order_202005.csv',
#  'm_area.csv',
#  'm_store.csv',
#  '.ipynb_checkpoints']

# %%
tbl_order_file = os.path.join(current_dir, "tbl_order_*.csv")
tbl_order_file
# Out:
# '/Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_*.csv'

# %%
import glob
tbl_order_files = glob.glob(tbl_order_file)
tbl_order_files
# Out:
# ['/Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_202006.csv',
#  '/Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_202004.csv',
#  '/Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_202005.csv']

# %%
order_all = pd.DataFrame()
file = tbl_order_files[0]
order_data = pd.read_csv(file)

print(f"{file}:{len(order_data)}")

order_all = pd.concat([order_all, order_data], ignore_index=True)
order_all
# Out:
# /Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_202006.csv:233301
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       16514392        64   C44271355         49         56527968
# 1       28342394        12   C98307866         98         46924304
# 2       29799587       174   C59484037         45         47054474
# 3       96960753        23   C57278332         70         60848267
# 4       52147209         7   C36890849         80         20633593
# ...          ...       ...         ...        ...              ...
# 233296  90872494       191   C35992970         46         51884378
# 233297  30167637        35   C53126526         88          6295273
# 233298  85345862       118   C25099070         32         15733308
# 233299  73038887       100   C27421314         84         67608099
# 233300  14799648        39   C90614204          5         13300147
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0       2020-06-01 11:00:00  2020-06-01 11:55:00             0          2732
# 1       2020-06-01 11:00:00  2020-06-01 11:52:00             0          2064
# 2       2020-06-01 11:00:00  2020-06-01 11:25:00             0          3900
# 3       2020-06-01 11:00:00  2020-06-01 11:45:00             0          2750
# 4       2020-06-01 11:00:00  2020-06-01 11:23:00             0          2328
# ...                     ...                  ...           ...           ...
# 233296  2020-06-30 21:58:58  2020-06-30 22:43:58             1          2112
# 233297  2020-06-30 21:58:58  2020-06-30 22:36:58             0          4462
# 233298  2020-06-30 21:58:58  2020-06-30 22:42:58             0          3865
# 233299  2020-06-30 21:58:58  2020-06-30 22:21:58             0          3319
# 233300  2020-06-30 21:58:58  2020-06-30 22:38:58             0          2064
#
#         status
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 233296       1
# 233297       2
# 233298       2
# 233299       2
# 233300       2
#
# [233301 rows x 10 columns]

# %%
order_all = pd.DataFrame()
for file in tbl_order_files:
    order_data = pd.read_csv(file)
    print(f"{file}:{len(order_data)}")
    order_all = pd.concat([order_all, order_data], ignore_index=True)
# Out:
# /Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_202006.csv:233301
# /Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_202004.csv:233260
# /Users/akifumiabe/PycharmProjects/MLs_100K_C1/notebooks/tbl_order_202005.csv:241139

# %%
order_all
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       16514392        64   C44271355         49         56527968
# 1       28342394        12   C98307866         98         46924304
# 2       29799587       174   C59484037         45         47054474
# 3       96960753        23   C57278332         70         60848267
# 4       52147209         7   C36890849         80         20633593
# ...          ...       ...         ...        ...              ...
# 707695  47039360       154   C39765066         90         27121351
# 707696  61054188        94   C19465010         41         61513298
# 707697  45288914        11   C23883838         40         65359139
# 707698  41608372       149   C48350551         43         42138977
# 707699  40316733       169   C49087342         61         59737067
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0       2020-06-01 11:00:00  2020-06-01 11:55:00             0          2732
# 1       2020-06-01 11:00:00  2020-06-01 11:52:00             0          2064
# 2       2020-06-01 11:00:00  2020-06-01 11:25:00             0          3900
# 3       2020-06-01 11:00:00  2020-06-01 11:45:00             0          2750
# 4       2020-06-01 11:00:00  2020-06-01 11:23:00             0          2328
# ...                     ...                  ...           ...           ...
# 707695  2020-05-31 21:58:58  2020-05-31 22:42:58             1          2363
# 707696  2020-05-31 21:58:58  2020-05-31 22:40:58             0          2112
# 707697  2020-05-31 21:58:58  2020-05-31 22:38:58             0          3838
# 707698  2020-05-31 21:58:58  2020-05-31 22:52:58             0          1899
# 707699  2020-05-31 21:58:58  2020-05-31 22:08:58             0          3901
#
#         status
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2
# ...        ...
# 707695       1
# 707696       2
# 707697       2
# 707698       2
# 707699       2
#
# [707700 rows x 10 columns]

# %%
order_all.isnull().sum()
# Out:
# order_id             0
# store_id             0
# customer_id          0
# coupon_cd            0
# sales_detail_id      0
# order_accept_date    0
# delivered_date       0
# takeout_flag         0
# total_amount         0
# status               0
# dtype: int64

# %%
order_all.describe()
# Out:
#            order_id       store_id      coupon_cd  sales_detail_id  \
# count  7.077000e+05  707700.000000  707700.000000     7.077000e+05
# mean   5.000989e+07     103.934565      49.514363     5.000335e+07
# std    2.889226e+07      86.374451      28.882605     2.885575e+07
# min    2.200000e+01       1.000000       0.000000     4.600000e+01
# 25%    2.501247e+07      51.000000      25.000000     2.504502e+07
# 50%    4.999655e+07      99.000000      49.000000     5.004506e+07
# 75%    7.508014e+07     148.000000      75.000000     7.499707e+07
# max    9.999980e+07     999.000000      99.000000     9.999965e+07
#
#         takeout_flag   total_amount         status
# count  707700.000000  707700.000000  707700.000000
# mean        0.259864    2960.651814       3.082908
# std         0.438560     954.378771       2.836278
# min         0.000000     698.000000       1.000000
# 25%         0.000000    2308.000000       2.000000
# 50%         0.000000    2808.000000       2.000000
# 75%         1.000000    3617.000000       2.000000
# max         1.000000    5100.000000       9.000000

# %%
order_all["total_amount"].describe()
# Out:
# count    707700.000000
# mean       2960.651814
# std         954.378771
# min         698.000000
# 25%        2308.000000
# 50%        2808.000000
# 75%        3617.000000
# max        5100.000000
# Name: total_amount, dtype: float64

# %%
print(order_all["order_accept_date"].min())
print(order_all["order_accept_date"].max())
print(order_all["delivered_date"].max())
print(order_all["delivered_date"].min())
# Out:
# 2020-04-01 11:00:00
# 2020-06-30 21:58:58
# 2020-06-30 22:55:56
# 2020-04-01 11:10:00

# %%
order_all = order_all.loc[order_all["store_id"] != 999]
order_all.shape
# Out:
# (703880, 10)

# %%
order_all.describe()
# Out:
#            order_id       store_id      coupon_cd  sales_detail_id  \
# count  7.038800e+05  703880.000000  703880.000000     7.038800e+05
# mean   5.001673e+07      99.076990      49.516098     5.000004e+07
# std    2.889339e+07      55.942693      28.882841     2.885464e+07
# min    2.200000e+01       1.000000       0.000000     4.600000e+01
# 25%    2.501570e+07      51.000000      25.000000     2.504034e+07
# 50%    5.000930e+07      99.000000      49.000000     5.004219e+07
# 75%    7.508612e+07     147.000000      75.000000     7.499172e+07
# max    9.999980e+07     196.000000      99.000000     9.999965e+07
#
#         takeout_flag   total_amount         status
# count  703880.000000  703880.000000  703880.000000
# mean        0.259872    2959.949248       3.082704
# std         0.438565     954.367273       2.836106
# min         0.000000     698.000000       1.000000
# 25%         0.000000    2308.000000       2.000000
# 50%         0.000000    2808.000000       2.000000
# 75%         1.000000    3617.000000       2.000000
# max         1.000000    5100.000000       9.000000

# %%
m_store.shape
# Out:
# (197, 3)

# %%
order_all = pd.merge(order_all, m_store, on="store_id", how="left")
order_all.head()
# Out:
#    order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0  16514392        64   C44271355         49         56527968
# 1  28342394        12   C98307866         98         46924304
# 2  29799587       174   C59484037         45         47054474
# 3  96960753        23   C57278332         70         60848267
# 4  52147209         7   C36890849         80         20633593
#
#      order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0  2020-06-01 11:00:00  2020-06-01 11:55:00             0          2732
# 1  2020-06-01 11:00:00  2020-06-01 11:52:00             0          2064
# 2  2020-06-01 11:00:00  2020-06-01 11:25:00             0          3900
# 3  2020-06-01 11:00:00  2020-06-01 11:45:00             0          2750
# 4  2020-06-01 11:00:00  2020-06-01 11:23:00             0          2328
#
#    status store_name area_cd
# 0       2       西東京店      TK
# 1       2       西葛西店      TK
# 2       2        新座店      SA
# 3       2        江東店      TK
# 4       2       東尾久店      TK

# %%
order_all.shape
# Out:
# (703880, 12)

# %%
m_area.shape
# Out:
# (7, 3)

# %%
order_all = pd.merge(order_all, m_area, on="area_cd", how="left")
order_all
# Out:
#         order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0       16514392        64   C44271355         49         56527968
# 1       28342394        12   C98307866         98         46924304
# 2       29799587       174   C59484037         45         47054474
# 3       96960753        23   C57278332         70         60848267
# 4       52147209         7   C36890849         80         20633593
# ...          ...       ...         ...        ...              ...
# 703875  47039360       154   C39765066         90         27121351
# 703876  61054188        94   C19465010         41         61513298
# 703877  45288914        11   C23883838         40         65359139
# 703878  41608372       149   C48350551         43         42138977
# 703879  40316733       169   C49087342         61         59737067
#
#           order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0       2020-06-01 11:00:00  2020-06-01 11:55:00             0          2732
# 1       2020-06-01 11:00:00  2020-06-01 11:52:00             0          2064
# 2       2020-06-01 11:00:00  2020-06-01 11:25:00             0          3900
# 3       2020-06-01 11:00:00  2020-06-01 11:45:00             0          2750
# 4       2020-06-01 11:00:00  2020-06-01 11:23:00             0          2328
# ...                     ...                  ...           ...           ...
# 703875  2020-05-31 21:58:58  2020-05-31 22:42:58             1          2363
# 703876  2020-05-31 21:58:58  2020-05-31 22:40:58             0          2112
# 703877  2020-05-31 21:58:58  2020-05-31 22:38:58             0          3838
# 703878  2020-05-31 21:58:58  2020-05-31 22:52:58             0          1899
# 703879  2020-05-31 21:58:58  2020-05-31 22:08:58             0          3901
#
#         status store_name area_cd wide_area narrow_area
# 0            2       西東京店      TK        東京          東京
# 1            2       西葛西店      TK        東京          東京
# 2            2        新座店      SA        埼玉          埼玉
# 3            2        江東店      TK        東京          東京
# 4            2       東尾久店      TK        東京          東京
# ...        ...        ...     ...       ...         ...
# 703875       1        入間店      SA        埼玉          埼玉
# 703876       2        鎌倉店      KN       神奈川         神奈川
# 703877       2       江戸川店      TK        東京          東京
# 703878       2        松戸店      CH        千葉          千葉
# 703879       2        狭山店      SA        埼玉          埼玉
#
# [703880 rows x 14 columns]

# %%
order_all.loc[order_all["takeout_flag"]==0, "takeout_name"] = "デリバリー"
order_all.loc[order_all["takeout_flag"]==1, "takeout_name"] = "お持ち帰り"
order_all.head()
# Out:
#    order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0  16514392        64   C44271355         49         56527968
# 1  28342394        12   C98307866         98         46924304
# 2  29799587       174   C59484037         45         47054474
# 3  96960753        23   C57278332         70         60848267
# 4  52147209         7   C36890849         80         20633593
#
#      order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0  2020-06-01 11:00:00  2020-06-01 11:55:00             0          2732
# 1  2020-06-01 11:00:00  2020-06-01 11:52:00             0          2064
# 2  2020-06-01 11:00:00  2020-06-01 11:25:00             0          3900
# 3  2020-06-01 11:00:00  2020-06-01 11:45:00             0          2750
# 4  2020-06-01 11:00:00  2020-06-01 11:23:00             0          2328
#
#    status store_name area_cd wide_area narrow_area takeout_name
# 0       2       西東京店      TK        東京          東京        デリバリー
# 1       2       西葛西店      TK        東京          東京        デリバリー
# 2       2        新座店      SA        埼玉          埼玉        デリバリー
# 3       2        江東店      TK        東京          東京        デリバリー
# 4       2       東尾久店      TK        東京          東京        デリバリー

# %%
order_all.loc[order_all["status"]==0, "status_name"] = "受付"
order_all.loc[order_all["status"]==1, "status_name"] = "お支払済"
order_all.loc[order_all["status"]==2, "status_name"] = "お渡し済"
order_all.loc[order_all["status"]==9, "status_name"] = "キャンセル"
order_all.head()
# Out:
#    order_id  store_id customer_id  coupon_cd  sales_detail_id  \
# 0  16514392        64   C44271355         49         56527968
# 1  28342394        12   C98307866         98         46924304
# 2  29799587       174   C59484037         45         47054474
# 3  96960753        23   C57278332         70         60848267
# 4  52147209         7   C36890849         80         20633593
#
#      order_accept_date       delivered_date  takeout_flag  total_amount  \
# 0  2020-06-01 11:00:00  2020-06-01 11:55:00             0          2732
# 1  2020-06-01 11:00:00  2020-06-01 11:52:00             0          2064
# 2  2020-06-01 11:00:00  2020-06-01 11:25:00             0          3900
# 3  2020-06-01 11:00:00  2020-06-01 11:45:00             0          2750
# 4  2020-06-01 11:00:00  2020-06-01 11:23:00             0          2328
#
#    status store_name area_cd wide_area narrow_area takeout_name status_name
# 0       2       西東京店      TK        東京          東京        デリバリー        お渡し済
# 1       2       西葛西店      TK        東京          東京        デリバリー        お渡し済
# 2       2        新座店      SA        埼玉          埼玉        デリバリー        お渡し済
# 3       2        江東店      TK        東京          東京        デリバリー        お渡し済
# 4       2       東尾久店      TK        東京          東京        デリバリー        お渡し済

# %%
output_dir = os.path.join(current_dir, "output_data")
os.makedirs(output_dir, exist_ok=True)

# %%
output_file = os.path.join(output_dir, "order_data.csv")
order_all.to_csv(output_file, index=False)
